# %%
# %load_ext sql
# %sql postgresql://postgres:changeme1234@localhost:5432/ny_taxi
# Out:
# Connecting to 'postgresql://postgres:***@localhost:5432/ny_taxi'

# %%
# %%sql
# CREATE SCHEMA IF NOT EXISTS raw;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/ny_taxi'
# ++
# ||
# ++
# ++

# %%
# %%sql
# DROP TABLE IF EXISTS raw.yellow_taxi_raw;
#
# CREATE TABLE raw.yellow_taxi_raw (
#     vendor_id TEXT,
#     pickup_datetime TEXT,
#     dropoff_datetime TEXT,
#     passenger_count TEXT,
#     trip_distance TEXT,
#     ratecode_id TEXT,
#     store_and_fwd_flag TEXT,
#     pulocation_id TEXT,
#     dolocation_id TEXT,
#     payment_type TEXT,
#     fare_amount TEXT,
#     extra TEXT,
#     mta_tax TEXT,
#     tip_amount TEXT,
#     tolls_amount TEXT,
#     improvement_surcharge TEXT,
#     total_amount TEXT,
#     congestion_surcharge TEXT,
#     airport_fee TEXT
# );
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/ny_taxi'
# ++
# ||
# ++
# ++

# %%
# %%bash
# psql postgresql://postgres:changeme1234@localhost:5432/ny_taxi <<'SQL'
# \copy raw.yellow_taxi_raw FROM '/workspaces/student-lakehouse/nivel-0/data/yellow_tripdata_2024-01.csv' CSV HEADER;
# SQL
# Out:
# COPY 2964624
