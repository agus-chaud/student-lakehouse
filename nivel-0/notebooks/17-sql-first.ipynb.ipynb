# %%
# %%bash
# psql postgresql://postgres:changeme1234@localhost:5432/postgres -c "SELECT 1;"
# Out:
#  ?column?
# ----------
#         1
# (1 row)

# %%
# %%bash
# psql postgresql://postgres:changeme1234@localhost:5432/postgres <<'SQL'
# SELECT
#     table_schema,
#     table_name
# FROM information_schema.tables
# WHERE table_type = 'BASE TABLE'
# ORDER BY table_schema, table_name
# LIMIT 10;
# SQL
# Out:
#     table_schema    |       table_name
# --------------------+-------------------------
#  information_schema | sql_features
#  information_schema | sql_implementation_info
#  information_schema | sql_parts
#  information_schema | sql_sizing
#  pg_catalog         | pg_aggregate
#  pg_catalog         | pg_am
#  pg_catalog         | pg_amop
#  pg_catalog         | pg_amproc
#  pg_catalog         | pg_attrdef
#  pg_catalog         | pg_attribute
# (10 rows)

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:changeme1234@localhost:5432/postgres
# Out:
# Connecting to 'postgresql://postgres:***@localhost:5432/postgres'

# %%
# %%sql
# SELECT
#     table_schema,
#     table_name
# FROM information_schema.tables
# WHERE table_type = 'BASE TABLE'
# ORDER BY table_schema, table_name;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/postgres'
# 66 rows affected.
# +--------------------+-------------------------+
# |    table_schema    |        table_name       |
# +--------------------+-------------------------+
# | information_schema |       sql_features      |
# | information_schema | sql_implementation_info |
# | information_schema |        sql_parts        |
# | information_schema |        sql_sizing       |
# |     pg_catalog     |       pg_aggregate      |
# |     pg_catalog     |          pg_am          |
# |     pg_catalog     |         pg_amop         |
# |     pg_catalog     |        pg_amproc        |
# |     pg_catalog     |        pg_attrdef       |
# |     pg_catalog     |       pg_attribute      |
# +--------------------+-------------------------+
# Truncated to displaylimit of 10.
